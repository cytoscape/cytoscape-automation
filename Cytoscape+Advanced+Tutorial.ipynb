# %%
Installation Instructions

Make sure you have Python3 and R installed
Install Jupyter
Install IRKernel: https://plot.ly/r/using-r-in-jupyter-notebooks/
install.packages(c('repr', 'IRdisplay', 'pbdZMQ', 'devtools’))
devtools::install_github('IRkernel/IRkernel’)
IRkernel::installspec()

Install rpy2 and other dependencies:
  pip3 install rpy2
  pip3 install numpy
  pip3 install pandas

# %%
#Cytoscape Tutorial: Advanced Topics

#Detailed outline
#2:30-2:50 – Introductory (20 min)

library(IRdisplay)

display_jpeg(file = '/Users/adamtreister/Desktop/haring.jpg')

# %%
demo(smooth)
# Out:
# 	demo(smooth)
# 	---- ~~~~~~
#
# > ### This used to be in   example(smooth) before we had package-specific demos
# > #  Copyright (C) 1997-2009 The R Core Team
# >
# > require(stats); require(graphics); require(datasets)
#
# > op <- par(mfrow = c(1,1))
#
# > ## The help(smooth) examples:
# > example(smooth, package="stats")
#
# smooth> require(graphics)
#
# smooth> ## see also   demo(smooth) !
# smooth>
# smooth> x1 <- c(4, 1, 3, 6, 6, 4, 1, 6, 2, 4, 2) # very artificial
#
# smooth> (x3R <- smooth(x1, "3R")) # 2 iterations of "3"
# 3R Tukey smoother resulting from  smooth(x = x1, kind = "3R")
#  used 2 iterations
#  [1] 3 3 3 6 6 4 4 4 2 2 2
#
# smooth> smooth(x3R, kind = "S")
# S Tukey smoother resulting from  smooth(x = x3R, kind = "S")
#  changed
#  [1] 3 3 3 3 4 4 4 4 2 2 2
#
# smooth> sm.3RS <- function(x, ...)
# smooth+    smooth(smooth(x, "3R", ...), "S", ...)
#
# smooth> y <- c(1, 1, 19:1)
#
# smooth> plot(y, main = "misbehaviour of \"3RSR\"", col.main = 3)
#
# ...

# %%
Introductions
General network biology overview
·       Cytoscape intro (consortium/history)
o   Roadmap: theme of integration/protocol
o   3.5/3.6 features
·       Introduce tutorial protocol
o   Functional enrichment of RNA-seq data
o   Use this protocol as the context and examples for subsequent sections...

# %%
2:50-3:30 – Intermediate (40 min)
·       Getting data
o   Types of data (networks, datasets), sources, and relevant apps
o   How to choose a network source: String, GeneMANIA, NDEx, WikiPathways
·       Network visualization overview
o   Style mappers & layouts
o   Apps: enhancedGraphics, etc
·       Network analysis overview
o   clusterMaker, BiNGO/ClueGO, etc

# %%
3:30-4:00 – Hands On (Advanced) (30 min)
·       R integration via CyREST
o  Start with dataset of calculated diff expression values (fold change)
o  Determine gene list
o  Launch Cytoscape from shell and connect

# %%
#4:00-4:15
#·       Coffee break
#<img src="https://octodex.github.com/images/yaktocat.png",width=100>
 browseURL('https://www.google.com/imgres?imgurl=http%3A%2F%2Fsawadacoffee.com%2Fwp-content%2Fuploads%2FSawada-Coffee-10DEC2015-003.jpg&imgrefurl=http%3A%2F%2Fsawadacoffee.com%2F&docid=4Be0umO3n46plM&tbnid=muIwkBE48flLsM%3A&vet=10ahUKEwjO9sHYn_XTAhWnhFQKHU-5C64QMwiQASgAMAA..i&w=1600&h=1067&bih=829&biw=1647&q=coffee%20images&ved=0ahUKEwjO9sHYn_XTAhWnhFQKHU-5C64QMwiQASgAMAA&iact=mrc&uact=8')

# %%
4:15-6:00 – Advanced (105 min)
·       R integration via CyREST  (continued)
o  Query string via CyREST
o   Inject tabular data (fold changes, p-Value) into Cytoscape and set styles, etc.
o  Explore network in Cytoscape
	o Hierarchical cluster & view heatmap
	o Play with styles and layouts

o   Exporting images and sessions
o   GSEA example through enrichment map & auto-annotate
·       Python integration via CyREST
o  Launch Cytoscape from shell and connect
o  Query String via CyREST
·       Cytoscape commands scripting [Scooter]
: advanced (now with loops and args!)
·       Additional advanced topics, per time and interest:
o   Export to web and publishing
o   CyBrowser (new!)

# %%
------------------------------------------- (Probably not) -------------------------------------------
o   cyAnimator
o   Groups and sets
o   Custom linkouts on nodes/edges
o   Shared sessions 
o   NDex
